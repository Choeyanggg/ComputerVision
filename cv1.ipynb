# %% [markdown]
# <a href="https://colab.research.google.com/github/Choeyanggg/ComputerVision/blob/main/cv1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opencv-python

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img=cv2.imread("/content/dog.png")

# %%
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(859.5), np.float64(572.5), np.float64(-0.5))

# %%
print(img.shape)
# Out:
# (573, 860, 3)

# %%
gray=cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)
plt.imshow(gray,cmap='gray')
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(859.5), np.float64(572.5), np.float64(-0.5))

# %%
crop=img[50:100,50:100]
plt.imshow(crop)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(49.5), np.float64(49.5), np.float64(-0.5))

# %%
resized=cv2.resize(img,(100,100))
plt.imshow(resized)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(99.5), np.float64(99.5), np.float64(-0.5))

# %%
(h,w)=img.shape[:2]
center=(w//2,h//2)

matrix=cv2.getRotationMatrix2D(center,45,1.0)
rotated=cv2.warpAffine(img,matrix,(w,h))
plt.imshow(rotated)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(859.5), np.float64(572.5), np.float64(-0.5))

# %%
r, g, b = img[:,:,0], img[:,:,1], img[:,:,2]

plt.imshow(r, cmap='Reds')
plt.title("Red Channel")
plt.show()

# %%
bright = np.clip(img + 50, 0, 255)

plt.imshow(bright)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(859.5), np.float64(572.5), np.float64(-0.5))

# %%
plt.hist(img.ravel(), bins=256)
plt.title("Pixel Intensity Distribution")
plt.show()
